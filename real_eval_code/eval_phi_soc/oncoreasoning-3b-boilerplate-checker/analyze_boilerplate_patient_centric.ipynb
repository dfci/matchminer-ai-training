# %%
import pandas as pd
import glob
import os

# %%
input_frame = pd.read_csv("boilerplate_results_patient_centric_soc.csv")

# %%
input_frame.info()

# %%
predictions = input_frame.groupby(['prompt_id'])['exclusion_result'].mean()

# %%
predictions.head()

# %%
predictions.shape

# %%
all_files = glob.glob(os.path.join('../boilerplates_for_spaces_for_patient_checks/', "*.csv"))

if not all_files:
    print(f"No CSV files found in the directory: {directory_path}")

list_of_dfs = []
for file_path in all_files:
    try:
        df = pd.read_csv(file_path)
        list_of_dfs.append(df)
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        continue

if list_of_dfs:
    gold = pd.concat(list_of_dfs, ignore_index=True)
else:
    print("No DataFrames could be successfully loaded.")

# %%
gold.info()

# %%
gold = gold.sort_values(by='Unnamed: 0').reset_index()

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(gold.exclusion_result, predictions)

# %%
from utils_102023 import eval_model

# %%
eval_model(predictions, gold.exclusion_result, graph=True)
